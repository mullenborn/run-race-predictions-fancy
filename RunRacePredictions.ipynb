# %%
#%pip install nbformat

# %%
import pandas as pd
import json
import os
import datetime
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go

# %%
# Set directory path
dir_path = "garmin-data/garmin-data-dump-2026-04-08/DI_CONNECT/DI-Connect-Metrics/"

# Create empty list to store DataFrames
df_list = []

# Loop through each file in directory
for filename in os.listdir(dir_path):
    if filename.endswith(".json") and filename.startswith("RunRacePredictions"):
        # Read JSON data from file
        filepath = os.path.join(dir_path, filename)
        with open(filepath, "r") as f:
            data = json.load(f)
        # Create DataFrame from JSON data
        df = pd.DataFrame(data)
        # Append DataFrame to list
        df_list.append(df)

# ------------------------------------- add amendments file to list -------------------------------------
# add amendments file to list
with open("garmin-data/RunRacePredictions_amendments.json", "r") as f:
    data = json.load(f)
df = pd.DataFrame(data)
df_list.append(df)
# ------------------------------------- get additions from file -------------------------------------
# get additions from file
with open("garmin-data/RunRacePredictions_additions.json", "r") as f:
    data = json.load(f)
# get events from data
events = data.get("events", [])
events_df = pd.DataFrame(events)

# Concatenate list of DataFrames into one collective DataFrame
collective_df = pd.concat(df_list)

# Drop duplicate rows based on calendarDate, keeping only the last recorded row
collective_df = collective_df.drop_duplicates(subset="calendarDate", keep="last")
# sort list by calendarDate
collective_df = collective_df.sort_values("calendarDate")
# remove userProfilePK, timestamp and deviceId columns
collective_df = collective_df.drop(columns=["userProfilePK", "timestamp", "deviceId"])

# %%
print(events_df)
# Out:
#    calendarDate                eventName      eventType  raceTime
# 0    2021-09-19            CPH Half 2021  Half Marathon      6831
# 1    2022-06-06           Royal Run 2022             5K      1455
# 2    2022-08-29                 DHL 2022             5K      1450
# 3    2022-09-18            CPH Half 2022  Half Marathon      6388
# 4    2023-05-29           Royal Run 2023             5K      1296
# 5    2023-06-10  Broløbet Storebælt 2023  Half Marathon      6439
# 6    2023-08-28                 DHL 2023             5K      1257
# 7    2023-09-17            CPH Half 2023  Half Marathon      5985
# 8    2023-10-15        Sydkystløbet 2023  Half Marathon      5628
# 9    2024-05-05       CPH  Marathon 2024       Marathon     14355
# 10   2024-08-26                 DHL 2024             5K      1387
# 11   2024-09-15            CPH Half 2024  Half Marathon      6009
# 12   2024-11-03    Lufthavnen Rundt 2024  Half Marathon      5690
# ...

# %%
# show the DataFrame
# print(collective_df)
# collective_df.info()
collective_df.to_csv("garmin-data/RunRacePredictions.csv", index=False)

# %%
plot_title = (
    "Race Time Predictions - Generated on "
    + datetime.datetime.now().strftime("%d-%m-%Y %H:%M:%S")
    + " - Data cut off at 2026-04-08"
)
color = ["green", "green", "yellow", "red", "red"]

# Find fastest times for each event type
fastest_5k = None
fastest_10k = None
fastest_half = None
fastest_marathon = None

fastest_5k_event = None
fastest_10k_event = None
fastest_half_event = None
fastest_marathon_event = None

if not events_df.empty:
    events_5k = events_df[events_df["eventType"] == "5K"]
    events_10k = events_df[events_df["eventType"] == "10K"]
    events_half = events_df[events_df["eventType"] == "Half Marathon"]
    events_marathon = events_df[events_df["eventType"] == "Marathon"]
    
    if not events_5k.empty:
        fastest_5k = events_5k["raceTime"].min()
        fastest_5k_event = events_5k[events_5k["raceTime"] == fastest_5k].iloc[0]
    
    if not events_10k.empty:
        fastest_10k = events_10k["raceTime"].min()
        fastest_10k_event = events_10k[events_10k["raceTime"] == fastest_10k].iloc[0]
    
    if not events_half.empty:
        fastest_half = events_half["raceTime"].min()
        fastest_half_event = events_half[events_half["raceTime"] == fastest_half].iloc[0]
    
    if not events_marathon.empty:
        fastest_marathon = events_marathon["raceTime"].min()
        fastest_marathon_event = events_marathon[events_marathon["raceTime"] == fastest_marathon].iloc[0]

# create a plotly figure
fig = go.Figure()

# Keep track of trace indices for proper visibility control
trace_indices = {
    '5k_prediction': None,
    '5k_results': None,
    '5k_fastest': None,
    '10k_prediction': None,
    '10k_results': None,
    '10k_fastest': None,
    'half_prediction': None,
    'half_results': None,
    'half_fastest': None,
    'marathon_prediction': None,
    'marathon_results': None,
    'marathon_fastest': None
}

current_trace_index = 0

# add a scatter plot of raceTime5K vs. calendarDate
marker = dict(
    colorscale=color,
    color=collective_df["raceTime5K"],
    showscale=False,
    cmin=875,
    cmax=1825,
    colorbar=dict(
        thickness=5,
        tickvals=[900, 1050, 1200, 1350, 1500, 1650, 1800],
        ticktext=[
            "00:15:00",
            "00:17:30",
            "00:20:00",
            "00:22:30",
            "00:25:00",
            "00:27:30",
            "00:30:00",
        ],
        title="Color Scale",
        tickformat="%H:%M:%S",
        tickmode="array",
        outlinewidth=0,
    ),
)
fig.add_trace(
    go.Scatter(
        x=collective_df["calendarDate"],
        y=pd.to_datetime(collective_df["raceTime5K"], unit="s"),
        name="5K",
        line=dict(color="white"),
        marker=marker,
    )
)
trace_indices['5k_prediction'] = current_trace_index
current_trace_index += 1

# Add actual 5K race results as stars
events_5k = events_df[events_df["eventType"] == "5K"]
if not events_5k.empty:
    # Add regular 5K results
    fig.add_trace(
        go.Scatter(
            x=events_5k["calendarDate"],
            y=pd.to_datetime(events_5k["raceTime"], unit="s"),
            mode="markers",
            marker=dict(
                symbol="star",
                size=15,
                color="cyan",
                line=dict(color="white", width=2)
            ),
            name="5K Results",
            text=events_5k["eventName"],
            hovertemplate="<b>%{text}</b><br>Date: %{x}<br>Time: %{y}<extra></extra>",
            showlegend=False
        )
    )
    trace_indices['5k_results'] = current_trace_index
    current_trace_index += 1
    
    # Add fastest 5K result as yellow star
    if fastest_5k_event is not None:
        fig.add_trace(
            go.Scatter(
                x=[fastest_5k_event["calendarDate"]],
                y=[pd.to_datetime(fastest_5k_event["raceTime"], unit="s")],
                mode="markers",
                marker=dict(
                    symbol="star",
                    size=20,
                    color="yellow",
                    line=dict(color="yellow", width=3)
                ),
                name="Fastest 5K",
                text=[f"FASTEST: {fastest_5k_event['eventName']}"],
                hovertemplate="<b>%{text}</b><br>Date: %{x}<br>Time: %{y}<extra></extra>",
                showlegend=False
            )
        )
        trace_indices['5k_fastest'] = current_trace_index
        current_trace_index += 1

# add a scatter plot of raceTime10K vs. calendarDate
marker = dict(
    colorscale=color,
    color=collective_df["raceTime10K"],
    showscale=False,
    cmin=1750,
    cmax=3650,
    colorbar=dict(
        thickness=5,
        tickvals=[1800, 2100, 2400, 2700, 3000, 3300, 3600],
        ticktext=[
            "00:30:00",
            "00:35:00",
            "00:40:00",
            "00:45:00",
            "00:50:00",
            "00:55:00",
            "00:60:00",
        ],
        title="Color Scale",
        tickformat="%H:%M:%S",
        tickmode="array",
        outlinewidth=0,
    ),
)
fig.add_trace(
    go.Scatter(
        x=collective_df["calendarDate"],
        y=pd.to_datetime(collective_df["raceTime10K"], unit="s"),
        name="10K",
        line=dict(color="white"),
        marker=marker,
    )
)
trace_indices['10k_prediction'] = current_trace_index
current_trace_index += 1

# Add actual 10K race results as stars
events_10k = events_df[events_df["eventType"] == "10K"]
if not events_10k.empty:
    # Add regular 10K results
    fig.add_trace(
        go.Scatter(
            x=events_10k["calendarDate"],
            y=pd.to_datetime(events_10k["raceTime"], unit="s"),
            mode="markers",
            marker=dict(
                symbol="star",
                size=15,
                color="cyan",
                line=dict(color="white", width=2)
            ),
            name="10K Results",
            text=events_10k["eventName"],
            hovertemplate="<b>%{text}</b><br>Date: %{x}<br>Time: %{y}<extra></extra>",
            showlegend=False
        )
    )
    trace_indices['10k_results'] = current_trace_index
    current_trace_index += 1
    
    # Add fastest 10K result as yellow star
    if fastest_10k_event is not None:
        fig.add_trace(
            go.Scatter(
                x=[fastest_10k_event["calendarDate"]],
                y=[pd.to_datetime(fastest_10k_event["raceTime"], unit="s")],
                mode="markers",
                marker=dict(
                    symbol="star",
                    size=20,
                    color="yellow",
                    line=dict(color="yellow", width=3)
                ),
                name="Fastest 10K",
                text=[f"FASTEST: {fastest_10k_event['eventName']}"],
                hovertemplate="<b>%{text}</b><br>Date: %{x}<br>Time: %{y}<extra></extra>",
                showlegend=False
            )
        )
        trace_indices['10k_fastest'] = current_trace_index
        current_trace_index += 1

# Add a line plot of raceTimeHalf vs. calendarDate
marker = dict(
    colorscale=color,
    color=collective_df["raceTimeHalf"],
    showscale=False,
    cmin=3495,
    cmax=9105,
    colorbar=dict(
        thickness=5,
        tickvals=[3600, 4500, 5400, 6300, 7200, 8100, 9000],
        ticktext=[
            "01:00:00",
            "01:15:00",
            "01:30:00",
            "01:45:00",
            "02:00:00",
            "02:15:00",
            "02:30:00",
        ],
        title="Color Scale",
        tickformat="%H:%M:%S",
        tickmode="array",
        outlinewidth=0,
    ),
)
fig.add_trace(
    go.Scatter(
        x=collective_df["calendarDate"],
        y=pd.to_datetime(collective_df["raceTimeHalf"], unit="s"),
        name="Half Marathon",
        line=dict(color="white"),
        marker=marker,
    )
)
trace_indices['half_prediction'] = current_trace_index
current_trace_index += 1

# Add actual Half Marathon race results as stars
events_half = events_df[events_df["eventType"] == "Half Marathon"]
if not events_half.empty:
    # Add regular Half Marathon results
    fig.add_trace(
        go.Scatter(
            x=events_half["calendarDate"],
            y=pd.to_datetime(events_half["raceTime"], unit="s"),
            mode="markers",
            marker=dict(
                symbol="star",
                size=15,
                color="cyan",
                line=dict(color="white", width=2)
            ),
            name="Half Marathon Results",
            text=events_half["eventName"],
            hovertemplate="<b>%{text}</b><br>Date: %{x}<br>Time: %{y}<extra></extra>",
            showlegend=False
        )
    )
    trace_indices['half_results'] = current_trace_index
    current_trace_index += 1
    
    # Add fastest Half Marathon result as yellow star
    if fastest_half_event is not None:
        fig.add_trace(
            go.Scatter(
                x=[fastest_half_event["calendarDate"]],
                y=[pd.to_datetime(fastest_half_event["raceTime"], unit="s")],
                mode="markers",
                marker=dict(
                    symbol="star",
                    size=20,
                    color="yellow",
                    line=dict(color="yellow", width=3)
                ),
                name="Fastest Half Marathon",
                text=[f"FASTEST: {fastest_half_event['eventName']}"],
                hovertemplate="<b>%{text}</b><br>Date: %{x}<br>Time: %{y}<extra></extra>",
                showlegend=False
            )
        )
        trace_indices['half_fastest'] = current_trace_index
        current_trace_index += 1

# add a scatter plot of raceTimeMarathon vs. calendarDate
marker = dict(
    colorscale=color,
    color=collective_df["raceTimeMarathon"],
    showscale=False,
    cmin=6990,
    cmax=18210,
    colorbar=dict(
        thickness=5,
        tickvals=[7200, 9000, 10800, 12600, 14400, 16200, 18000],
        ticktext=[
            "2:00:00",
            "2:30:00",
            "3:00:00",
            "3:30:00",
            "4:00:00",
            "4:30:00",
            "5:00:00",
        ],
        title="Color Scale",
        tickformat="%H:%M:%S",
        tickmode="array",
        outlinewidth=0,
    ),
)
fig.add_trace(
    go.Scatter(
        x=collective_df["calendarDate"],
        y=pd.to_datetime(collective_df["raceTimeMarathon"], unit="s"),
        name="Marathon",
        line=dict(color="white"),
        marker=marker,
    )
)
trace_indices['marathon_prediction'] = current_trace_index
current_trace_index += 1

# Add actual Marathon race results as stars
events_marathon = events_df[events_df["eventType"] == "Marathon"]
if not events_marathon.empty:
    # Add regular Marathon results
    fig.add_trace(
        go.Scatter(
            x=events_marathon["calendarDate"],
            y=pd.to_datetime(events_marathon["raceTime"], unit="s"),
            mode="markers",
            marker=dict(
                symbol="star",
                size=15,
                color="cyan",
                line=dict(color="white", width=2)
            ),
            name="Marathon Results",
            text=events_marathon["eventName"],
            hovertemplate="<b>%{text}</b><br>Date: %{x}<br>Time: %{y}<extra></extra>",
            showlegend=False
        )
    )
    trace_indices['marathon_results'] = current_trace_index
    current_trace_index += 1
    
    # Add fastest Marathon result as yellow star
    if fastest_marathon_event is not None:
        fig.add_trace(
            go.Scatter(
                x=[fastest_marathon_event["calendarDate"]],
                y=[pd.to_datetime(fastest_marathon_event["raceTime"], unit="s")],
                mode="markers",
                marker=dict(
                    symbol="star",
                    size=20,
                    color="yellow",
                    line=dict(color="yellow", width=3)
                ),
                name="Fastest Marathon",
                text=[f"FASTEST: {fastest_marathon_event['eventName']}"],
                hovertemplate="<b>%{text}</b><br>Date: %{x}<br>Time: %{y}<extra></extra>",
                showlegend=False
            )
        )
        trace_indices['marathon_fastest'] = current_trace_index
        current_trace_index += 1

# Set the default plot title
fig.update_layout(
    title_text="Test Race Time Predictions - Generated on "
    + datetime.datetime.now().strftime("%d-%m-%Y %H:%M:%S")
    + " - Data cut off at 2026-04-08"
)

# Set the x-axis title
fig.update_xaxes(title_text="Date")

# Set the y-axis title
fig.update_yaxes(title_text="Race Time Prediction (hh:mm:SS)")

# Set the axes tick settings
fig.update_yaxes(tickformat="%H:%M:%S")
fig.update_xaxes(tickformat="%d-%m-%Y")

# Reverse the y-axis so the fastest times are at the top
fig.update_yaxes(autorange="reversed")

# reverse the y-axis of the color scale
fig.update_layout(coloraxis_colorbar=dict(yanchor="top", y=1))

# Set the hover text
fig.update_traces(mode="markers+lines", hovertemplate=None)

# set crosshairs
fig.update_xaxes(showspikes=True, spikemode="across")
fig.update_yaxes(showspikes=True, spikemode="across")

# Create visibility arrays dynamically based on actual traces
total_traces = current_trace_index
visible_all = [True] * total_traces

# Create individual category visibility arrays
def create_visibility_array(category_indices):
    visibility = [False] * total_traces
    for idx in category_indices:
        if idx is not None:
            visibility[idx] = True
    return visibility

visible_5k = create_visibility_array([
    trace_indices['5k_prediction'],
    trace_indices['5k_results'], 
    trace_indices['5k_fastest']
])

visible_10k = create_visibility_array([
    trace_indices['10k_prediction'],
    trace_indices['10k_results'],
    trace_indices['10k_fastest']
])

visible_half = create_visibility_array([
    trace_indices['half_prediction'],
    trace_indices['half_results'],
    trace_indices['half_fastest']
])

visible_marathon = create_visibility_array([
    trace_indices['marathon_prediction'],
    trace_indices['marathon_results'],
    trace_indices['marathon_fastest']
])

# create dropdown menu to select which line to show on the graph
fig.update_layout(
    updatemenus=[
        dict(
            buttons=list(
                [
                    dict(
                        label="All",
                        method="update",
                        args=[
                            {
                                "visible": visible_all,
                                "marker.showscale": False,
                            },
                            {
                                "title": "All " + plot_title,
                            },
                        ],
                    ),
                    dict(
                        label="5K",
                        method="update",
                        args=[
                            {
                                "visible": visible_5k,
                                "marker.showscale": True,
                            },
                            {
                                "title": "5K " + plot_title,
                            },
                        ],
                    ),
                    dict(
                        label="10K",
                        method="update",
                        args=[
                            {
                                "visible": visible_10k,
                                "marker.showscale": True,
                            },
                            {
                                "title": "10K " + plot_title,
                            },
                        ],
                    ),
                    dict(
                        label="Half Marathon",
                        method="update",
                        args=[
                            {
                                "visible": visible_half,
                                "marker.showscale": True,
                            },
                            {
                                "title": "Half Marathon " + plot_title,
                            },
                        ],
                    ),
                    dict(
                        label="Marathon",
                        method="update",
                        args=[
                            {
                                "visible": visible_marathon,
                                "marker.showscale": True,
                            },
                            {
                                "title": "Marathon " + plot_title,
                            },
                        ],
                    ),
                ]
            ),
            bgcolor="Grey",
            font=dict(color="Black"),
            type="buttons",
            direction="left",
            showactive=True,
            xanchor="left",
            y=1.03,
            yanchor="top",
        )
    ]
)

# update the layout theme
fig.update_layout(template="plotly_dark", showlegend=False, title_x=0.5)

# update

# Plot the figure
fig.show()
fig.write_html("garmin-data/RunRacePredictions.html")
